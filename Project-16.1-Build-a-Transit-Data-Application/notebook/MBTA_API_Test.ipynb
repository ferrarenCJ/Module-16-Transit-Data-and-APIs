# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

# %%
import urllib.request
import json

# %%
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())

    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)

    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)

    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 135,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 4,
#                 "direction_id": 0,
#                 "label": "1898",
#                 "latitude": 42.33215,
#                 "longitude": -71.07957,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:55-04:00"
#             },
#             "id": "y1898",
#             "links": {
#                 "self": "/vehicles/y1898"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "6",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307137",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 135,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 18,
#                 "direction_id": 1,
#                 "label": "1892",
#                 "latitude": 42.33502,
#                 "longitude": -71.07526,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:43-04:00"
#             },
#             "id": "y1892",
#             "links": {
#                 "self": "/vehicles/y1892"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "854",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79306276",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 90,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1886",
#                 "latitude": 42.32986,
#                 "longitude": -71.08414,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:55-04:00"
#             },
#             "id": "y1886",
#             "links": {
#                 "self": "/vehicles/y1886"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307147",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": null,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 9,
#                 "direction_id": 1,
#                 "label": "1873",
#                 "latitude": 42.360698,
#                 "longitude": -71.095915,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:01-04:00"
#             },
#             "id": "y1873",
#             "links": {
#                 "self": "/vehicles/y1873"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "74",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307187",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 113,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 2,
#                 "direction_id": 1,
#                 "label": "1870",
#                 "latitude": 42.3709,
#                 "longitude": -71.11584,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:04-04:00"
#             },
#             "id": "y1870",
#             "links": {
#                 "self": "/vehicles/y1870"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "66",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307131",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 270,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 1,
#                 "label": "1867",
#                 "latitude": 42.37297,
#                 "longitude": -71.11722,
#                 "occupancy_status": "FULL",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:47-04:00"
#             },
#             "id": "y1867",
#             "links": {
#                 "self": "/vehicles/y1867"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "110",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307134",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 180,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 12,
#                 "direction_id": 1,
#                 "label": "1851",
#                 "latitude": 42.347582,
#                 "longitude": -71.088183,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:02-04:00"
#             },
#             "id": "y1851",
#             "links": {
#                 "self": "/vehicles/y1851"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "79",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79306279",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 8,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 3,
#                 "direction_id": 0,
#                 "label": "1850",
#                 "latitude": 42.332503,
#                 "longitude": -71.081232,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:08-04:00"
#             },
#             "id": "y1850",
#             "links": {
#                 "self": "/vehicles/y1850"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "2",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307143",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 90,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1825",
#                 "latitude": 42.32986,
#                 "longitude": -71.08379,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:49-04:00"
#             },
#             "id": "y1825",
#             "links": {
#                 "self": "/vehicles/y1825"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307132",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": null,
#                 "carriages": [],
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 13,
#                 "direction_id": 0,
#                 "label": "1818",
#                 "latitude": 42.346754,
#                 "longitude": -71.087588,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:52-04:00"
#             },
#             "id": "y1818",
#             "links": {
#                 "self": "/vehicles/y1818"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "93",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307153",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 180,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 12,
#                 "direction_id": 1,
#                 "label": "1810",
#                 "latitude": 42.347354,
#                 "longitude": -71.088018,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:00-04:00"
#             },
#             "id": "y1810",
#             "links": {
#                 "self": "/vehicles/y1810"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "79",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307182",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": null,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 10,
#                 "direction_id": 0,
#                 "label": "1805",
#                 "latitude": 42.341532,
#                 "longitude": -71.082924,
#                 "occupancy_status": "FULL",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:24:48-04:00"
#             },
#             "id": "y1805",
#             "links": {
#                 "self": "/vehicles/y1805"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "188",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307130",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": null,
#                 "carriages": [],
#                 "current_status": "STOPPED_AT",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1799",
#                 "latitude": 42.32047,
#                 "longitude": -71.071664,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "revenue": "REVENUE",
#                 "speed": null,
#                 "updated_at": "2026-09-18T16:25:00-04:00"
#             },
#             "id": "y1799",
#             "links": {
#                 "self": "/vehicles/y1799"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "79307140",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-18",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79306276",
#             "links": {
#                 "self": "/trips/79306276"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-5",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79306279",
#             "links": {
#                 "self": "/trips/79306279"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-36",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307130",
#             "links": {
#                 "self": "/trips/79307130"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-21",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307131",
#             "links": {
#                 "self": "/trips/79307131"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-16",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307132",
#             "links": {
#                 "self": "/trips/79307132"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-37",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307134",
#             "links": {
#                 "self": "/trips/79307134"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-14",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307137",
#             "links": {
#                 "self": "/trips/79307137"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-15",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307140",
#             "links": {
#                 "self": "/trips/79307140"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-23",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307143",
#             "links": {
#                 "self": "/trips/79307143"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-17",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307147",
#             "links": {
#                 "self": "/trips/79307147"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-22",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307153",
#             "links": {
#                 "self": "/trips/79307153"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010154",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-19",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307182",
#             "links": {
#                 "self": "/trips/79307182"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-20",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "revenue": "REVENUE",
#                 "wheelchair_accessible": 1
#             },
#             "id": "79307187",
#             "links": {
#                 "self": "/trips/79307187"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "BUS20264-sbc46wf1-Weekday-01",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010156",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }
